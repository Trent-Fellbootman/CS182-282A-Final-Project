# %%
from base import *
from point_dataset import *
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
taylor_pair_dis = PointPairDistribution.random_taylor(latent_dim=3,
                                                      dis_A_dim=2,
                                                      dis_B_dim=2,
                                                      latent_range=1,
                                                      max_order=2,
                                                      coeff_range=1,
                                                      noise_std_A=0.05,
                                                      noise_std_B=0,
                                                      key=random.PRNGKey(2))

# %%
print(taylor_pair_dis)
# Out:
# PointPairDataset:
# latent distribution:
# 	dimensionality: 3
# 	sampler: <function uniform at 0x7fefeb5aeb90>
# 	sampler configs: {'minval': -1, 'maxval': 1}
# transformation A:
# 	(x_0, x_1, x_2) ->
# 	(6.90e-02 + 1.48e-01 x_0^1 + -6.79e-01 x_1^1 + -1.16e-01 x_2^1 + 2.39e-01 x_0^2 + -9.18e-01 x_0^1 x_1^1 + -9.06e-01 x_0^1 x_2^1 + -8.33e-01 x_1^2 + -6.57e-01 x_1^1 x_2^1 + 7.67e-01 x_2^2,
# 	4.58e-01 + 5.47e-01 x_0^1 + -4.57e-02 x_1^1 + -6.37e-01 x_2^1 + 5.46e-01 x_0^2 + 5.43e-01 x_0^1 x_1^1 + -4.71e-01 x_0^1 x_2^1 + 2.46e-01 x_1^2 + -9.56e-03 x_1^1 x_2^1 + 5.41e-01 x_2^2)
# transformation B:
# 	(x_0, x_1, x_2) ->
# 	(4.37e-01 + 5.71e-01 x_0^1 + 1.00e-02 x_1^1 + -8.54e-01 x_2^1 + 4.78e-01 x_0^2 + 7.81e-01 x_0^1 x_1^1 + -3.25e-01 x_0^1 x_2^1 + -4.28e-02 x_1^2 + -9.57e-01 x_1^1 x_2^1 + 6.36e-01 x_2^2,
# 	-7.13e-01 + -6.15e-01 x_0^1 + -4.65e-01 x_1^1 + 5.09e-01 x_2^1 + -8.79e-01 x_0^2 + -8.89e-01 x_0^1 x_1^1 + -9.20e-02 x_0^1 x_2^1 + 1.62e-01 x_1^2 + 2.84e-01 x_1^1 x_2^1 + -7.46e-01 x_2^2)
# Noise std A: 5.00e-02
# Noise std B: 0.00e+00

# %%
samples = taylor_pair_dis.draw_samples(100)

# %%
samples[0].shape
# Out:
# (100, 3)

# %%
samples[1].shape
# Out:
# (100, 2)

# %%
samples[2].shape
# Out:
# (100, 2)

# %%
dataset = taylor_pair_dis.generate_dataset(100)

# %%
fig = dataset.create_visualization()

# %%
fig.show()
# Out:
# <div>                            <div id="4f6377fe-6ae6-4d24-916f-a49a9ccb88b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f6377fe-6ae6-4d24-916f-a49a9ccb88b2")) {                    Plotly.newPlot(                        "4f6377fe-6ae6-4d24-916f-a49a9ccb88b2",                        [{"marker":{"color":[1.0447725057601929,0.8403194546699524,0.7905333638191223,1.2183150053024292,0.7041239142417908,0.8967719674110413,0.5049490928649902,0.9025615453720093,0.9646256566047668,0.8192102313041687,0.9543092250823975,0.6230505704879761,1.0722074508666992,1.2401525974273682,1.1636583805084229,0.9907