# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from library.datasets.base import *
from library.datasets.utils import make_blobs
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %%
dataset = make_blobs(n_samples=1000, min_sigma=0, max_sigma=0.1)
# Out:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = make_blobs(n_samples=1000, min_sigma=0, max_sigma=0.1)
#
# File ~/college-files-fa22/cs182/CS182-282A-Final-Project/library/datasets/utils.py:255, in make_blobs(n_samples, n_clusters, n_dim, cluster_pos_sigma, min_sigma, max_sigma, key)
#     253 key, new_key1, new_key2 = random.split(key, num=3)
#     254 samples_per_cluster = n_samples // n_clusters
# --> 255 centers = random.multivariate_normal(new_key1, jnp.zeros((n_dim,)), jnp.eye(n_dim) * cluster_pos_sigma ** 2, (n_clusters,))
#     256 stds = random.uniform(new_key2, (n_clusters,), minval=min_sigma, maxval=max_sigma)
#     258 result = jnp.empty((samples_per_cluster * n_clusters, n_dim))
#
# ...

# %%
points = dataset.get_tensors()
print(points.shape)
# Out:
# (1000, 2)

# %%
px.scatter(x=points[:, 0], y=points[:, 1])
# Out:
# <div>                            <div id="f6b4b5aa-02f4-46ef-94ea-3aa53dcc1b3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6b4b5aa-02f4-46ef-94ea-3aa53dcc1b3d")) {                    Plotly.newPlot(                        "f6b4b5aa-02f4-46ef-94ea-3aa53dcc1b3d",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.37310194969177246,-0.4688199758529663,-0.38558927178382874,-0.3617000877857208,-0.3504799008369446,-0.46444448828697205,-0.35118669271469116,-0.24090471863746643,-0.39060717821121216,-0.4256924092769623,-0.4654850363731384,-0.29812905192375183,-0.41351407766342163,-0.416792482137
# ...

# %%
points
# Out:
# DeviceArray([[-0.37310195,  0.29776275],
#              [-0.46881998,  0.4063563 ],
#              [-0.38558927,  0.4496919 ],
#              ...,
#              [ 0.03414936, -0.13562888],
#              [ 0.0115185 , -0.07917506],
#              [-0.03405145, -0.08963608]], dtype=float32)
